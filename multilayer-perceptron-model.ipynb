# %% [markdown]
# # Load and Examine the Dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %% [markdown]
# # Load and Preview Data

# %%
# Load the CSV file
dataset_path = 'C:/Users/ibrah/Downloads/Met dataset - 2015-to-2022_12months.csv'
data = pd.read_csv(dataset_path)
print("Dataset Preview:")
# Display the first few rows of the dataset
data.head()
# Out:
# Dataset Preview:
#    x_coord  y_coord  year  groundfrost_1  groundfrost_2  groundfrost_3  \
# 0        1        1     1            NaN            NaN            NaN
# 1        1        1     1            NaN            NaN            NaN
# 2        1        1     1            NaN            NaN            NaN
# 3        1        1     1            NaN            NaN            NaN
# 4        1        1     1            NaN            NaN            NaN
#
#    groundfrost_4  groundfrost_5  groundfrost_6  groundfrost_7  ...  \
# 0            NaN            NaN            NaN            NaN  ...
# 1            NaN            NaN            NaN            NaN  ...
# 2            NaN            NaN            NaN            NaN  ...
# 3            NaN            NaN            NaN            NaN  ...
# 4            NaN            NaN            NaN            NaN  ...
#
#    rainfall_3  rainfall_4  rainfall_5  rainfall_6  rainfall_7  rainfall_8  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    rainfall_9  rainfall_10  rainfall_11  rainfall_12
# 0         NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN
# 3         NaN          NaN          NaN          NaN
# 4         NaN          NaN          NaN          NaN
#
# [5 rows x 111 columns]

# %% [markdown]
# # Handling Missing Values
# We'll fill missing values with the mean of each column.

# %%
# Fill missing values with the mean of each column
imputer = SimpleImputer(strategy='mean')
data_imputed = pd.DataFrame(imputer.fit_transform(data), columns=data.columns)
data_imputed
# Out:
#        x_coord  y_coord  year  groundfrost_1  groundfrost_2  groundfrost_3  \
# 0          1.0      1.0   1.0       7.967022       7.896864       7.882327
# 1          1.0      1.0   1.0       7.967022       7.896864       7.882327
# 2          1.0      1.0   1.0       7.967022       7.896864       7.882327
# 3          1.0      1.0   1.0       7.967022       7.896864       7.882327
# 4          1.0      1.0   1.0       7.967022       7.896864       7.882327
# ...        ...      ...   ...            ...            ...            ...
# 33230     23.0     23.0   8.0       7.967022       7.896864       7.882327
# 33231     23.0     23.0   8.0       7.967022       7.896864       7.882327
# 33232     23.0     23.0   8.0       7.967022       7.896864       7.882327
# 33233     23.0     23.0   8.0       7.967022       7.896864       7.882327
# 33234     23.0     23.0   8.0       7.967022       7.896864       7.882327
#
#        groundfrost_4  groundfrost_5  groundfrost_6  groundfrost_7  ...  \
# 0           7.836455        7.69597       7.654871       7.630654  ...
# 1           7.836455        7.69597       7.654871       7.630654  ...
# 2           7.836455        7.69597       7.654871       7.630654  ...
# 3           7.836455        7.69597       7.654871       7.630654  ...
# 4           7.836455        7.69597       7.654871       7.630654  ...
# ...              ...            ...            ...            ...  ...
# 33230       7.836455        7.69597       7.654871       7.630654  ...
# 33231       7.836455        7.69597       7.654871       7.630654  ...
# 33232       7.836455        7.69597       7.654871       7.630654  ...
# 33233       7.836455        7.69597       7.654871       7.630654  ...
# 33234       7.836455        7.69597       7.654871       7.630654  ...
#
#        rainfall_3  rainfall_4  rainfall_5  rainfall_6  rainfall_7  rainfall_8  \
# 0       95.995318   95.486136   95.844339   95.301693   95.216766   94.560505
# 1       95.995318   95.486136   95.844339   95.301693   95.216766   94.560505
# 2       95.995318   95.486136   95.844339   95.301693   95.216766   94.560505
# 3       95.995318   95.486136   95.844339   95.301693   95.216766   94.560505
# 4       95.995318   95.486136   95.844339   95.301693   95.216766   94.560505
# ...           ...         ...         ...         ...         ...         ...
# 33230   95.995318   95.486136   95.844339   95.301693   95.216766   94.560505
# 33231   95.995318   95.486136   95.844339   95.301693   95.216766   94.560505
# 33232   95.995318   95.486136   95.844339   95.301693   95.216766   94.560505
# 33233   95.995318   95.486136   95.844339   95.301693   95.216766   94.560505
# 33234   95.995318   95.486136   95.844339   95.301693   95.216766   94.560505
#
#        rainfall_9  rainfall_10  rainfall_11  rainfall_12
# 0       94.549497    95.647443    96.745711    96.063469
# 1       94.549497    95.647443    96.745711    96.063469
# 2       94.549497    95.647443    96.745711    96.063469
# 3       94.549497    95.647443    96.745711    96.063469
# 4       94.549497    95.647443    96.745711    96.063469
# ...           ...          ...          ...          ...
# 33230   94.549497    95.647443    96.745711    96.063469
# 33231   94.549497    95.647443    96.745711    96.063469
# 33232   94.549497    95.647443    96.745711    96.063469
# 33233   94.549497    95.647443    96.745711    96.063469
# 33234   94.549497    95.647443    96.745711    96.063469
#
# [33235 rows x 111 columns]

# %% [markdown]
# # Define feature columns for the model

# %%
# Define feature and target columns
features_columns = [f'{feature}_{month}' for feature in ['groundfrost', 'hurs', 'psl', 'sun', 'pv', 'sfcWind', 'tas', 'snowLying', 'rainfall'] for month in range(1, 13)]
# The target variable is the relative humidity for the next month
# Here we assume it's hurs_1 (next month after the 12th month)
target_column = 'hurs_1'

# %% [markdown]
# # Select Features and Target

# %%
# Selecting features and target
features = data_imputed[features_columns]
target = data_imputed[target_column]
# Select the most recent 12 months of data
recent_data = data_imputed[features_columns].iloc[-1].values.reshape(1, -1)

# %%
# Split data into train and test sets

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
import os

# Ensure the directory exists
save_dir = 'C:/Users/ibrah/Downloads/data/'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
# Save processed data to avoid repeated preprocessing
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=features_columns)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=features_columns)

X_train_scaled_df.to_csv(os.path.join(save_dir, 'X_train_scaled.csv'), index=False)
X_test_scaled_df.to_csv(os.path.join(save_dir, 'X_test_scaled.csv'), index=False)
y_train.to_csv(os.path.join(save_dir, 'y_train.csv'), index=False)
y_test.to_csv(os.path.join(save_dir, 'y_test.csv'), index=False)

# %% [markdown]
# # Build and Train the MLP Model
# Build and train the MLP model using TensorFlow/Keras.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Define the model
model = Sequential([
    tf.keras.layers.Input(shape=(X_train_scaled.shape[1],)),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(1)  # Output layer for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# %%
# Display model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         6,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,089 (35.50 KB)
#  Trainable params: 9,089 (35.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model (early stopping to prevent overfitting)
early_stopping = tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
history = model.fit(X_train_scaled, y_train, epochs=50, validation_data=(X_test_scaled, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3755.1121 - mae: 52.4635 - val_loss: 25.5089 - val_mae: 2.4007
# Epoch 2/50
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 64.1646 - mae: 5.7353 - val_loss: 9.0271 - val_mae: 1.2536
# Epoch 3/50
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 46.3869 - mae: 5.1930 - val_loss: 8.6881 - val_mae: 1.4304
# Epoch 4/50
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 41.1154 - mae: 4.9609 - val_loss: 5.0326 - val_mae: 1.2500
# Epoch 5/50
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 38.0712 - mae: 4.8174 - val_loss: 7.4545 - val_mae: 1.0856
# Epoch 6/50
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 32.8528 - mae: 4.4983 - val_loss: 6.2498 - val_mae: 1.0050
# Epoch 7/50
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 28.0584 - mae: 4.1462 - val_loss: 14.0897 - val_mae: 2.0900
# Epoch 8/50
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 24.1424 - mae: 3.8570 - val_loss: 14.3881 - val_mae: 2.4323
# Epoch 9/50
# 831/831 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 20.8862 - mae: 3.5859 - val_loss: 14.4684 - val_mae: 1.9698

# %%
# Display training history
history_df = pd.DataFrame(history.history)
display(history_df.head())
# Out:
#           loss        mae   val_loss   val_mae
# 0  1698.807373  28.107025  25.508904  2.400707
# 1    57.123936   5.540397   9.027093  1.253639
# 2    44.899055   5.123977   8.688098  1.430443
# 3    40.886936   4.938976   5.032596  1.250011
# 4    37.046677   4.742568   7.454462  1.085601

# %%
# Evaluate the model
test_loss = model.evaluate(X_test_scaled, y_test)
# Print the results
print(f"Evaluation Loss: {test_loss[0]:.4f}")
# Out:
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.9508 - mae: 1.2538
# Evaluation Loss: 5.0326

# %%
# Save the model
model.save('relative_humidity_forecast_model.keras')

# Load the model
loaded_model = tf.keras.models.load_model('relative_humidity_forecast_model.keras')

# %%
# Load the scaler used during training
scaler_fit = StandardScaler()
X_train_scaled = pd.read_csv('C:/Users/ibrah/Downloads/data/X_train_scaled.csv')
scaler_fit.fit(X_train_scaled)  # Re-fit the scaler with training data
# Out:
# StandardScaler()

# %%
# Transform the recent data
recent_data_scaled = scaler.transform(recent_data)
display(recent_data_scaled)
# Out:
# C:\Users\ibrah\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[7.96702165e+00, 7.89686383e+00, 7.88232651e+00, 7.83645465e+00,
#         7.69596962e+00, 7.65487103e+00, 7.63065383e+00, 7.63068824e+00,
#         7.64555404e+00, 7.65010731e+00, 7.65511434e+00, 7.81018989e+00,
#         8.26272479e+01, 8.25987880e+01, 8.25202254e+01, 8.24718923e+01,
#         8.24944778e+01, 8.24750084e+01, 8.24446102e+01, 8.23961418e+01,
#         8.24027257e+01, 8.24337494e+01, 8.24600718e+01, 8.24818662e+01,
#         1.01377579e+03, 1.01378433e+03, 1.01386686e+03, 1.01384323e+03,
#         1.01379201e+03, 1.01381578e+03, 1.01383211e+03, 1.01389076e+03,
#         1.01389862e+03, 1.01382270e+03, 1.01365848e+03, 1.01364422e+03,
#         1.20370605e+02, 1.20551623e+02, 1.21618347e+02, 1.22179224e+02,
#         1.21509594e+02, 1.21777405e+02, 1.21653630e+02, 1.22232766e+02,
#         1.21903138e+02, 1.21336267e+02, 1.20925937e+02, 1.21099494e+02,
#         1.00820338e+01, 1.00902638e+01, 1.00996445e+01, 1.01108122e+01,
#         1.01417015e+01, 1.01724939e+01, 1.02002191e+01, 1.02134081e+01,
#         1.02035004e+01, 1.02097839e+01, 1.01999847e+01, 1.01665515e+01,
#         4.66480399e+00, 4.67263718e+00, 4.66489272e+00, 4.65062286e+00,
#         4.65276430e+00, 4.64176550e+00, 4.63573599e+00, 4.62668978e+00,
#         4.62444130e+00, 4.63892731e+00, 4.65471310e+00, 4.63492988e+00,
#         9.38480342e+00, 9.40755078e+00, 9.44520582e+00, 9.47518251e+00,
#         9.52086166e+00, 9.57148712e+00, 9.61704726e+00, 9.64412059e+00,
#         9.62916324e+00, 9.62585119e+00, 9.60530284e+00, 9.54311325e+00,
#         8.38159805e-01, 7.90530930e-01, 7.53087155e-01, 7.41633344e-01,
#         7.39536413e-01, 7.38943009e-01, 7.38943009e-01, 7.39476949e-01,
#         7.39476949e-01, 7.39476949e-01, 7.39476949e-01, 7.89058331e-01,
#         9.63783031e+01, 9.63401340e+01, 9.59953175e+01, 9.54861361e+01,
#         9.58443387e+01, 9.53016934e+01, 9.52167655e+01, 9.45605054e+01,
#         9.45494965e+01, 9.56474426e+01, 9.67457111e+01, 9.60634695e+01]])

# %%
# Predict the relative humidity for the next month
predicted_humidity = loaded_model.predict(recent_data_scaled)
print(f"Predicted Relative Humidity for next month: {predicted_humidity[0][0]:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# Predicted Relative Humidity for next month: 8369.19%
